# %%
from pychunk.chunkers.python_chunker import PythonChunker

files_path = ["pychunk/"]
chunker = PythonChunker(files_path=files_path)
# Out:
# Imported files:  ['/Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/types.py', '/Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py', '/Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py', '/Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/python_chunker.py', '/Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/base.py', '/Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/files_handler.py', '/Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/nodes_utils.py']

# %%
nodes = chunker.find_relationships()

# %%
from pychunk.nodes.types import NodeRelationshipType

all_nodes = {}
for file_path, node_of_file in nodes.items():
    for id, node in node_of_file.items():
        all_nodes[id] = node

for _, nodes_file in nodes.items():
    for id, node in nodes_file.items():
        if len(node.filter_relationships(NodeRelationshipType.OTHER)) > 5:
            print(node)
            print("Text of this node: \n", node.content)  
            node_relationships = node.filter_relationships(NodeRelationshipType.OTHER)
            print("Relationships of this node: \n")
            for n, rel in enumerate(node_relationships):
                print(f"Relationship {n+1} -> {rel}: \n", all_nodes[rel].content)
                print("\n")
            print("\n")
            print("-"*100)
            print(" ")
# Out:
# BaseNode(node_type = NodeType.CLASS, metadata = {'hash': 'edc68045ff8f0c3ef934ee80349b11ec00bac23ecf2378c071cdce2271040dc6', 'lines_of_code': (12, 22), 'additional_metadata': {'parent_class': 'BaseNode', 'class_name': 'FunctionNode'}})
# Text of this node:
#  class FunctionNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, List[Type['BaseNode']] | Type['BaseNode']]] | None = None):
#
#         super(FunctionNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 4 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 5 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 6 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.CLASS, metadata = {'hash': '2c0789369b086d37720d87bc0512ad7663138dc0df70fee5a7d859bfbeb7d9c3', 'lines_of_code': (25, 35), 'additional_metadata': {'parent_class': 'BaseNode', 'class_name': 'MethodNode'}})
# Text of this node:
#  class MethodNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(MethodNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 4 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 5 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 6 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.CLASS, metadata = {'hash': '603adb4e07f7ea9865894149897d51b3d5e180e7ffbb529ccb453497abed1a55', 'lines_of_code': (38, 48), 'additional_metadata': {'parent_class': 'BaseNode', 'class_name': 'ClassNode'}})
# Text of this node:
#  class ClassNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ClassNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 4 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 5 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 6 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.CLASS, metadata = {'hash': 'c7978a52cb471db84f25e43a1027208f386109d2c35b61dd8d1a16cbf4e30c4d', 'lines_of_code': (51, 61), 'additional_metadata': {'parent_class': 'BaseNode', 'class_name': 'CodeNode'}})
# Text of this node:
#  class CodeNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(CodeNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 4 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 5 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 6 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.CLASS, metadata = {'hash': 'f1c71f4f07c68192f445f2434d1370350b76f85ef629df75abb990558f569b81', 'lines_of_code': (64, 74), 'additional_metadata': {'parent_class': 'BaseNode', 'class_name': 'ModuleNode'}})
# Text of this node:
#  class ModuleNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ModuleNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 4 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 5 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 6 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.METHOD, metadata = {'hash': '88327d89b996c5ffe6c0c3aa50569b29e9453f896c7d33002856f5d61ef51e51', 'lines_of_code': (15, 22), 'additional_metadata': {'arguments': 'self', 'method_name': '__init__'}})
# Text of this node:
#       def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, List[Type['BaseNode']] | Type['BaseNode']]] | None = None):
#
#         super(FunctionNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> a6112671-d72d-4614-afa1-d261b00aff2c:
#  class FunctionNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, List[Type['BaseNode']] | Type['BaseNode']]] | None = None):
#
#         super(FunctionNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 4 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 5 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 6 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 7 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.METHOD, metadata = {'hash': 'f581fcc38e03c969e3430846e3873a7158ec71d5825e921db7e94b71425a0ea7', 'lines_of_code': (28, 35), 'additional_metadata': {'arguments': 'self', 'method_name': '__init__'}})
# Text of this node:
#       def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(MethodNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> 4ccf9f9f-88ad-43d9-b596-918c98f39038:
#  class MethodNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(MethodNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 4 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 5 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 6 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 7 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.METHOD, metadata = {'hash': '9aced5bb3da1bc03dd16cc1bbed326665aae537e7df045a54728e706b5096e6c', 'lines_of_code': (41, 48), 'additional_metadata': {'arguments': 'self', 'method_name': '__init__'}})
# Text of this node:
#       def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ClassNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> e7d153dd-0c0d-403f-b3ba-fce733f6f8d6:
#  class ClassNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ClassNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 4 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 5 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 6 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 7 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.METHOD, metadata = {'hash': '02e6c06ee27b7e244fcdffe4076620722b4e4dd10bdc41b9af6cfeb3ffd698a2', 'lines_of_code': (54, 61), 'additional_metadata': {'arguments': 'self', 'method_name': '__init__'}})
# Text of this node:
#       def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(CodeNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> f81369ce-e289-4eff-a507-c3776cb9688e:
#  class CodeNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(CodeNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 4 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 5 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 6 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 7 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.METHOD, metadata = {'hash': '0425dbb589e3160787b1aa2ef52cbf34c29bf124646653ad105f7aada3dfeb14', 'lines_of_code': (67, 74), 'additional_metadata': {'arguments': 'self', 'method_name': '__init__'}})
# Text of this node:
#       def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ModuleNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> c82d4a0e-ae57-408a-8944-c861c88f4730:
#  class ModuleNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ModuleNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 4 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 5 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 6 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 7 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.CLASS, metadata = {'hash': '35bb95c4e710a9443af65eae96ac6170127034f7b23d4954fe1a7221593abd64', 'lines_of_code': (18, 199), 'additional_metadata': {'parent_class': 'Chunker', 'class_name': 'PythonChunker'}})
# Text of this node:
#  class PythonChunker(Chunker):
#
#     _node_type_to_node_base: Dict[NodeType, Type['BaseNode']] = {
#         NodeType.CLASS: ClassNode,
#         NodeType.CODE: CodeNode,
#         NodeType.FUNCTION: FunctionNode,
#         NodeType.METHOD: MethodNode,
#         NodeType.MODULE: ModuleNode
#     }
#
#     _not_valid_relationships_to_look_pattern = r"^__[^_]*__$"
#
#     def __init__(self, files_path: str | List[str], hash_function: Optional[Callable] | None = None):
#         super(PythonChunker, self).__init__(files_path=files_path, hash_function=hash_function)
#
#     def _create_nodes_of_file(self, file_path: str) -> Dict[str, Type['BaseNode']]:
#
#         tmp_folder = self._file_handler.tmp_folder
#         if file_path.startswith("."): file_path = file_path[2:]
#         elif file_path.startswith(".."): file_path = file_path[3:]
#         file_name = file_path.replace("/", "_").split(".")[0]
#         command = f"./scripts/python-scripts/generate-node-metadata.sh {file_path} {tmp_folder}/{file_name}_info.txt > {tmp_folder}/{file_name}_final.txt 2> /dev/null"
#         subprocess.run(["bash", "-c", command])
#
#         nodes = {}
#         hashes = set()
#         classes_names_to_uuids = {}
#
#         for (code, lines_of_code, class_name, function_or_method_name, node_type, metadata) in create_nodes_from_file(f"{tmp_folder}/{file_name}_final.txt"):
#             if code is None or lines_of_code is None:
#                 continue
#             remove_commas_spaces_and_new_lines = code.replace(",", "").replace("\n", "").strip().replace(" ", "")
#             try:
#                 int(remove_commas_spaces_and_new_lines)
#                 continue
#             except Exception:
#                 pass
#
#             hash = self._hash_function(text=code)
#             if hash in hashes: continue
#             hashes.add(hash)
#             node_class = self._node_type_to_node_base[node_type]
#             node_object = node_class(
#                 text=code,
#                 node_type=node_type,
#                 file=file_path
#             )
#
#             if node_type == NodeType.CLASS:
#                 classes_names_to_uuids[class_name.replace(" ", "")] = node_object.id
#                 uuid_of_parent_node = None
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'parent_class': metadata.strip(), 'class_name': class_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.METHOD:
#                 uuid_of_parent_node = classes_names_to_uuids[class_name.replace(" ", "")]
#                 parent_node = nodes[uuid_of_parent_node]
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'arguments': metadata.strip(), 'method_name': function_or_method_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 node_object.add_relationship(parent_node, relationship_type=NodeRelationshipType.PARENT)
#                 parent_node.add_relationship(node_object, relationship_type=NodeRelationshipType.CHILD)
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.FUNCTION:
#
#                 node_metadata = NodeMetadata(
#                     hash=hash, lines_of_code=lines_of_code, additional_metadata={'arguments': metadata.strip(), 'function_name': function_or_method_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.CODE:
#                 node_metadata = NodeMetadata(
#                     hash=hash, lines_of_code=lines_of_code, additional_metadata=metadata if metadata else {}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.MODULE:
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'modules': metadata if metadata else {}}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#         return nodes
#
#     def _create_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         nodes = {}
#         for file in self._files_path:
#             try:
#                 nodes[file] = self._create_nodes_of_file(file_path=file)
#             except Exception as e:
#                 self._file_handler.delete_tmp_folder()
#                 raise e
#         return nodes
#
#     def find_relationships(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         try:
#             return self._create_relationships_of_nodes()
#         except Exception as e:
#             self._file_handler.delete_tmp_folder()
#             raise e
#
#     def _create_relationships_of_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#
#         nodes_of_files_dict = self._create_nodes()
#         nodes_of_files = []
#         for _, nodes_file in nodes_of_files_dict.items():
#             nodes_of_files.extend(list(nodes_file.values()))
#
#         tmp_folder = self._file_handler.tmp_folder
#
#         fields = ('class_name', 'function_name', 'method_name')
#         name_file = os.path.join(tmp_folder, "names.txt")
#         relationships_file = os.path.join(tmp_folder, "node_relationships.txt")
#
#         nodes = []
#         with open(name_file, "w") as names_file:
#             for field in fields:
#                 get_nodes_of_field = lambda n: [x for x in n if x.metadata['additional_metadata'].get(field) is not None]
#                 nodes_of_field = get_nodes_of_field(nodes_of_files)
#                 nodes.extend(nodes_of_field)
#             for node in nodes:
#                 node_metadata = node.metadata['additional_metadata']
#                 for field in fields:
#                     name = node_metadata.get(field)
#                     if name is None or re.match(self._not_valid_relationships_to_look_pattern, name): continue
#                     names_file.write(f"{name} {node.id} {node.file}\n")
#
#         for path in self._files_path:
#             command = f"./scripts/python-scripts/find-node-relationships.sh {name_file} {path} >> {relationships_file} 2> /dev/null"
#             subprocess.run(["bash", "-c", command])
#
#         with open(relationships_file, "r") as node_relationship_file:
#             lines = node_relationship_file.readlines()
#
#         start = False
#         get_node = lambda id_: [node for node in nodes_of_files if node.id == id_]
#         for line in lines:
#             if line.startswith("#- BEGIN"):
#
#                 start = True
#                 node_id = line.split(" ")[-2].strip()
#
#             elif line.startswith("#- END"):
#                 start = False
#
#             if start:
#                 parts = line.split(":")[-1].split("-")
#                 if len(parts) > 2:
#                     file_path = "-".join(parts[:-1]).strip()
#                     line_of_code = parts[-1].strip()
#                 else:
#                     file_path, line_of_code = line.split(":")[-1].split("-")[0].strip(), line.split(":")[-1].split("-")[-1].strip()
#                 if "#" in file_path: continue
#                 nodes_of_file = nodes_of_files_dict[file_path]
#                 node_relationship_with, = get_node(node_id)
#
#                 for node in nodes_of_file.values():
#
#                     lines_of_code = node.metadata.get('lines_of_code')
#                     is_node_relationsihp_with_its_child_node = node.check_relationship(node_relationship_with, relationship_type=NodeRelationshipType.CHILD)
#
#                     if lines_of_code is None or node == node_relationship_with or is_node_relationsihp_with_its_child_node: continue
#
#                     if int(lines_of_code[0]) <= int(line_of_code) <= int(lines_of_code[1]):
#                         node.add_relationship(node_relationship_with, NodeRelationshipType.OTHER, line_of_code)
#
#         self._file_handler.delete_tmp_folder()
#         return nodes_of_files_dict
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> c98fbff8-f57a-4877-8560-92c884513ef5:
#  class NodeMetadata(BaseModel):
#
#     hash: str
#     lines_of_code: Tuple[int, int] | None
#
#
#
# Relationship 4 -> a6112671-d72d-4614-afa1-d261b00aff2c:
#  class FunctionNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, List[Type['BaseNode']] | Type['BaseNode']]] | None = None):
#
#         super(FunctionNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 5 -> 4ccf9f9f-88ad-43d9-b596-918c98f39038:
#  class MethodNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(MethodNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 6 -> e7d153dd-0c0d-403f-b3ba-fce733f6f8d6:
#  class ClassNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ClassNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 7 -> f81369ce-e289-4eff-a507-c3776cb9688e:
#  class CodeNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(CodeNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 8 -> c82d4a0e-ae57-408a-8944-c861c88f4730:
#  class ModuleNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ModuleNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
#
#
# Relationship 9 -> 6325a418-823d-41d6-a1d4-49c8cefb22c4:
#
#
#
# Relationship 10 -> 2f95bc19-07d8-4a12-b014-6fb1a43d5f65:
#  class Chunker(ABC):
#
#     __extensions_to_type = {'*.py'}
#     temp_file_handler = TempFileHandler
#
#     def __init__(self, files_path: str | List[str],
#                  hash_function: Optional[Callable] | None = None,
#                  pattern: str = "*.py"):
#
#         if pattern not in self.__extensions_to_type:
#             raise ValueError(f"Your pattern is not implemented yet. Available: {self.__extensions_to_type}")
#         _files_path = files_path if isinstance(files_path, list) else [files_path]
#         self._files_path = []
#         for file_path in _files_path:
#             self._files_path.extend(self._recursive_retrieval_of_files(file_path=file_path))
#
#         self._hash_function = hash_function if hash_function else self._default_hash_function
#         self._file_handler = self.temp_file_handler()
#         print("Imported files: ", self._files_path)
#
#     @abstractmethod
#     def _create_nodes_of_file(self, file_path: str) -> Dict[str, Type['BaseNode']]:
#         raise NotImplementedError("You need to implement _create_nodes_of_file method.")
#
#     @abstractmethod
#     def _create_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         raise NotImplementedError("You need to implement __create_nodes method.")
#
#     @staticmethod
#     def _default_hash_function(text: str) -> str:
#
#         hasher = hashlib.new('sha256')
#         text = text.replace("\n", "").replace(" ", "")
#         if len(text) < 1:
#             return ''
#         hasher.update(text.encode('utf-8'))
#         return hasher.hexdigest()
#
#     @staticmethod
#     def _recursive_retrieval_of_files(file_path: str, pattern: str="*.py") -> List[str]:
#
#         if file_path.endswith(".py"):
#             return [file_path]
#
#         python_files = []
#         for path, _, files in os.walk(file_path):
#             if file_path.startswith("."):
#                 root_path = path.split("/")[-1]
#                 if root_path.startswith("."): continue
#
#             for name in files:
#                 if ".venv/" in path: continue
#                 if fnmatch(name, pattern) and name != "__init__.py":
#                     python_files.append(os.path.join(path, name))
#
#         python_files = [os.path.abspath(path) for path in python_files]
#         return python_files
#
#
#
# Relationship 11 -> 59c990be-c543-49e0-bff2-c28089a5c0f5:
#  def create_nodes_from_file(file: str) -> Generator[Tuple, None, None]:
#     lines = open(file).readlines()
#     modules_text = None
#     class_text = None
#     method_text = None
#     function_text = None
#     free_code = None
#
#     # TODO -> refactor this into smaller functions
#
#     for line in lines:
#
#         if line.startswith(Delimiter.module_delimiter[Pointer.start]):
#             modules_text = []
#             class_text = None
#             function_text = None
#             method_text = None
#             free_code = None
#
#             begin_module_line = True
#             end_module_line = False
#
#         elif line.startswith(Delimiter.class_delimiter[Pointer.start]):
#             class_text = []
#             modules_text = None
#             function_text = None
#             method_text = None
#             free_code = None
#
#             begin_class_line = True
#             end_class_line = False
#             class_name = line.replace(" ", "").split(":")[-1][:-3]
#
#
#         elif line.startswith(Delimiter.function_delimiter[Pointer.start]):
#
#             function_text = []
#             method_text = None
#             class_text = None
#             modules_text = None
#             free_code = None
#
#             begin_function_line = True
#             end_function_line = False
#
#         elif line.startswith(Delimiter.free_code_delimiter[Pointer.start]):
#
#             free_code = []
#             function_text = None
#             method_text = None
#             class_text = None
#             modules_text = None
#
#             begin_free_code = True
#             end_free_code = False
#
#         elif line.startswith(Delimiter.module_delimiter[Pointer.end]) and isinstance(modules_text, list):
#             modules_content = "".join(modules_text)
#             modules_text = None
#             end_module_line = True
#             yield modules_content, None , None, None, NodeType.MODULE, None
#
#         elif line.startswith(Delimiter.class_delimiter[Pointer.end]) and isinstance(class_text, list):
#             class_metadata = class_text[0].split(":")[-1]
#
#             try:
#                 begin_line, end_line = class_metadata.split("-")[-1].split(",")
#                 begin_line = begin_line.replace("\n", "")
#                 end_line = end_line.replace("\n", "")
#                 if not len(end_line.strip()):
#                     end_line = int(begin_line) + 1
#             except ValueError:
#                 begin_line = class_metadata.split("-")[-1].split(",")[0]
#                 end_line = int(begin_line) + 1
#
#             metadata = class_metadata.split(":")[-1].split("-")[0]
#             del class_text[0]
#             class_content = "".join(class_text)
#             class_text = None
#             end_class_line = True
#             begin_class_line = False
#             yield class_content, (int(begin_line), int(end_line)), class_name, None, NodeType.CLASS, metadata
#
#         elif line.startswith(Delimiter.function_delimiter[Pointer.end]) and isinstance(function_text, list):
#
#             end_function_line = True
#             begin_function_line = False
#             function_metadata = function_text[0]
#             metadata = function_text[0].split("Arguments:")[-1].split("-")[0]
#             function_name = line.split("FUNCTION:")[-1].replace(" ", "")[:-3]
#             begin_line, end_line = function_metadata.split("-")[-1].split(",")
#             if not len(end_line.strip()): end_line = int(begin_line) + 1
#             del function_text[0]
#             function_content = "".join(function_text)
#             function_text = None
#             yield (function_content,
#                   (int(begin_line),
#                    int(end_line)),
#                    None,
#                    function_name,
#                    NodeType.FUNCTION,
#                    metadata)
#
#         elif line.startswith(Delimiter.free_code_delimiter[Pointer.end]) and isinstance(free_code, list):
#             end_free_code = True
#             begin_free_code = False
#             code_metadata = free_code[0]
#             begin_line, end_line = code_metadata.split(":")[-1].split(",")
#             del free_code[0]
#             code_content = "".join(free_code)
#             free_code = None
#             yield (code_content,
#                   (int(begin_line),
#                    int(end_line)),
#                    None,
#                    None,
#                    NodeType.CODE,
#                    None)
#
#         if isinstance(modules_text, list):
#             if begin_module_line:
#                 begin_module_line = False
#                 continue
#             if end_module_line:
#                 continue
#
#             modules_text.append(line)
#
#         elif isinstance(class_text, list):
#             if begin_class_line:
#                 begin_class_line = False
#                 continue
#             if end_class_line:
#                 continue
#             class_text.append(line)
#
#         elif isinstance(function_text, list):
#             if begin_function_line:
#                 begin_function_line = False
#                 continue
#             if end_function_line:
#                 continue
#             function_text.append(line)
#
#         elif isinstance(free_code, list):
#             if begin_free_code:
#                 begin_free_code = False
#                 continue
#             if end_free_code:
#                 continue
#             free_code.append(line)
#
#
#     for line in lines:
#
#         if line.startswith(Delimiter.method_delimiter[Pointer.start]):
#             method_text = []
#             class_text = None
#             modules_text = None
#             function_text = None
#             free_code = None
#
#             begin_method_line = True
#             end_method_line = False
#
#         elif line.startswith(Delimiter.method_delimiter[Pointer.end]) and isinstance(method_text, list):
#             method_metadata = method_text[0]
#             metadata = method_metadata.split("Arguments:")[-1].split("-")[0]
#             class_name = line.split("CLASS")[-1].split(":")[0].replace(" ", "")
#             method_name = line.split("CLASS")[-1].split(":")[1].replace(" ", "")[:-3]
#             begin_line, end_line = method_metadata.split("-")[-1].split(",")
#             del method_text[0]
#             method_content = "".join(method_text)
#             method_text = None
#             end_method_line = True
#             begin_method_line = False
#
#             try:
#                 yield (method_content,
#                       (int(begin_line),
#                        int(end_line)),
#                        class_name,
#                        method_name,
#                        NodeType.METHOD,
#                        metadata)
#             except Exception as e:
#                 yield (None, None, None, None, None, None)
#
#         if isinstance(method_text, list):
#             if begin_method_line:
#                 begin_method_line = False
#                 continue
#             if end_method_line:
#                 continue
#             method_text.append(line)
#
#
#
# Relationship 12 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 13 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 14 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
# Relationship 15 -> 4ce1fcdc-fd26-44a0-bcbe-5baf8ac77f8b:
#      def relationships(self):
#         return self.__node_relationships
#
#
#
# Relationship 16 -> 1e137a39-99d0-42fe-9e6d-70bd259d7c2e:
#      def add_relationship(self, node: Type['BaseNode'], relationship_type: NodeRelationshipType, line_of_occurence: Optional[int] | None = None) -> None:
#         relationship_type = relationship_type.value
#         if relationship_type not in self.__node_relationships:
#             self.__node_relationships[relationship_type] = {node.id: [line_of_occurence]}
#         else:
#             if node.id in self.__node_relationships[relationship_type]:
#                 self.__node_relationships[relationship_type][node.id].append(line_of_occurence)
#             else:
#                 self.__node_relationships[relationship_type][node.id] = [line_of_occurence]
#
#
#
# Relationship 17 -> c487d933-c575-4f40-82c2-3a4d7f1fff55:
#      def check_relationship(self, node: Type['BaseNode'], relationship_type: NodeRelationshipType) -> bool:
#         try:
#             return node.id in self.__node_relationships[relationship_type.value]
#         except KeyError:
#             return False
#
#
#
# Relationship 18 -> d27d54ce-a4c1-4de0-a26e-bc5ea27e70e9:
#      def _create_nodes_of_file(self, file_path: str) -> Dict[str, Type['BaseNode']]:
#         raise NotImplementedError("You need to implement _create_nodes_of_file method.")
#
#
#
# Relationship 19 -> df7cd981-3e1f-4bf8-b2ab-351836d4042f:
#      def _create_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         raise NotImplementedError("You need to implement __create_nodes method.")
#
#
#
# Relationship 20 -> 05abe11f-2eed-42e3-bd2b-c104e7b11fbf:
#      def tmp_folder(self):
#         return self._tmp_folder
#
#
#
# Relationship 21 -> 7f48dbe1-cd27-4254-b6a3-3a740fc9840a:
#      def delete_tmp_folder(self) -> None:
#         shutil.rmtree(self._tmp_folder)
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.METHOD, metadata = {'hash': 'cee587999765482725fac45eeed96f431d470de1b48184d86af5fd7d2bd29bc7', 'lines_of_code': (35, 114), 'additional_metadata': {'arguments': 'self file_path: str', 'method_name': '_create_nodes_of_file'}})
# Text of this node:
#      def _create_nodes_of_file(self, file_path: str) -> Dict[str, Type['BaseNode']]:
#
#         tmp_folder = self._file_handler.tmp_folder
#         if file_path.startswith("."): file_path = file_path[2:]
#         elif file_path.startswith(".."): file_path = file_path[3:]
#         file_name = file_path.replace("/", "_").split(".")[0]
#         command = f"./scripts/python-scripts/generate-node-metadata.sh {file_path} {tmp_folder}/{file_name}_info.txt > {tmp_folder}/{file_name}_final.txt 2> /dev/null"
#         subprocess.run(["bash", "-c", command])
#
#         nodes = {}
#         hashes = set()
#         classes_names_to_uuids = {}
#
#         for (code, lines_of_code, class_name, function_or_method_name, node_type, metadata) in create_nodes_from_file(f"{tmp_folder}/{file_name}_final.txt"):
#             if code is None or lines_of_code is None:
#                 continue
#             remove_commas_spaces_and_new_lines = code.replace(",", "").replace("\n", "").strip().replace(" ", "")
#             try:
#                 int(remove_commas_spaces_and_new_lines)
#                 continue
#             except Exception:
#                 pass
#
#             hash = self._hash_function(text=code)
#             if hash in hashes: continue
#             hashes.add(hash)
#             node_class = self._node_type_to_node_base[node_type]
#             node_object = node_class(
#                 text=code,
#                 node_type=node_type,
#                 file=file_path
#             )
#
#             if node_type == NodeType.CLASS:
#                 classes_names_to_uuids[class_name.replace(" ", "")] = node_object.id
#                 uuid_of_parent_node = None
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'parent_class': metadata.strip(), 'class_name': class_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.METHOD:
#                 uuid_of_parent_node = classes_names_to_uuids[class_name.replace(" ", "")]
#                 parent_node = nodes[uuid_of_parent_node]
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'arguments': metadata.strip(), 'method_name': function_or_method_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
# ...
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'modules': metadata if metadata else {}}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#         return nodes
#
# Relationships of this node:
#
# Relationship 1 -> 285a8c63-c609-469b-a669-fc18d01719ed:
#  class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
#
#
# Relationship 2 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 3 -> c98fbff8-f57a-4877-8560-92c884513ef5:
#  class NodeMetadata(BaseModel):
#
#     hash: str
#     lines_of_code: Tuple[int, int] | None
#
#
#
# Relationship 4 -> 59c990be-c543-49e0-bff2-c28089a5c0f5:
#  def create_nodes_from_file(file: str) -> Generator[Tuple, None, None]:
#     lines = open(file).readlines()
#     modules_text = None
#     class_text = None
#     method_text = None
#     function_text = None
#     free_code = None
#
#     # TODO -> refactor this into smaller functions
#
#     for line in lines:
#
#         if line.startswith(Delimiter.module_delimiter[Pointer.start]):
#             modules_text = []
#             class_text = None
#             function_text = None
#             method_text = None
#             free_code = None
#
#             begin_module_line = True
#             end_module_line = False
#
#         elif line.startswith(Delimiter.class_delimiter[Pointer.start]):
#             class_text = []
#             modules_text = None
#             function_text = None
#             method_text = None
#             free_code = None
#
#             begin_class_line = True
#             end_class_line = False
#             class_name = line.replace(" ", "").split(":")[-1][:-3]
#
#
#         elif line.startswith(Delimiter.function_delimiter[Pointer.start]):
#
#             function_text = []
#             method_text = None
#             class_text = None
#             modules_text = None
#             free_code = None
#
#             begin_function_line = True
#             end_function_line = False
#
#         elif line.startswith(Delimiter.free_code_delimiter[Pointer.start]):
#
#             free_code = []
#             function_text = None
#             method_text = None
#             class_text = None
#             modules_text = None
#
#             begin_free_code = True
#             end_free_code = False
#
#         elif line.startswith(Delimiter.module_delimiter[Pointer.end]) and isinstance(modules_text, list):
#             modules_content = "".join(modules_text)
#             modules_text = None
#             end_module_line = True
#             yield modules_content, None , None, None, NodeType.MODULE, None
#
#         elif line.startswith(Delimiter.class_delimiter[Pointer.end]) and isinstance(class_text, list):
#             class_metadata = class_text[0].split(":")[-1]
#
#             try:
#                 begin_line, end_line = class_metadata.split("-")[-1].split(",")
#                 begin_line = begin_line.replace("\n", "")
#                 end_line = end_line.replace("\n", "")
#                 if not len(end_line.strip()):
#                     end_line = int(begin_line) + 1
#             except ValueError:
#                 begin_line = class_metadata.split("-")[-1].split(",")[0]
#                 end_line = int(begin_line) + 1
#
#             metadata = class_metadata.split(":")[-1].split("-")[0]
#             del class_text[0]
#             class_content = "".join(class_text)
#             class_text = None
#             end_class_line = True
#             begin_class_line = False
#             yield class_content, (int(begin_line), int(end_line)), class_name, None, NodeType.CLASS, metadata
#
#         elif line.startswith(Delimiter.function_delimiter[Pointer.end]) and isinstance(function_text, list):
#
#             end_function_line = True
#             begin_function_line = False
#             function_metadata = function_text[0]
#             metadata = function_text[0].split("Arguments:")[-1].split("-")[0]
#             function_name = line.split("FUNCTION:")[-1].replace(" ", "")[:-3]
#             begin_line, end_line = function_metadata.split("-")[-1].split(",")
#             if not len(end_line.strip()): end_line = int(begin_line) + 1
#             del function_text[0]
#             function_content = "".join(function_text)
#             function_text = None
#             yield (function_content,
#                   (int(begin_line),
#                    int(end_line)),
#                    None,
#                    function_name,
#                    NodeType.FUNCTION,
#                    metadata)
#
#         elif line.startswith(Delimiter.free_code_delimiter[Pointer.end]) and isinstance(free_code, list):
#             end_free_code = True
#             begin_free_code = False
#             code_metadata = free_code[0]
#             begin_line, end_line = code_metadata.split(":")[-1].split(",")
#             del free_code[0]
#             code_content = "".join(free_code)
#             free_code = None
#             yield (code_content,
#                   (int(begin_line),
#                    int(end_line)),
#                    None,
#                    None,
#                    NodeType.CODE,
#                    None)
#
#         if isinstance(modules_text, list):
#             if begin_module_line:
#                 begin_module_line = False
#                 continue
#             if end_module_line:
#                 continue
#
#             modules_text.append(line)
#
#         elif isinstance(class_text, list):
#             if begin_class_line:
#                 begin_class_line = False
#                 continue
#             if end_class_line:
#                 continue
#             class_text.append(line)
#
#         elif isinstance(function_text, list):
#             if begin_function_line:
#                 begin_function_line = False
#                 continue
#             if end_function_line:
#                 continue
#             function_text.append(line)
#
#         elif isinstance(free_code, list):
#             if begin_free_code:
#                 begin_free_code = False
#                 continue
#             if end_free_code:
#                 continue
#             free_code.append(line)
#
#
#     for line in lines:
#
#         if line.startswith(Delimiter.method_delimiter[Pointer.start]):
#             method_text = []
#             class_text = None
#             modules_text = None
#             function_text = None
#             free_code = None
#
#             begin_method_line = True
#             end_method_line = False
#
#         elif line.startswith(Delimiter.method_delimiter[Pointer.end]) and isinstance(method_text, list):
#             method_metadata = method_text[0]
#             metadata = method_metadata.split("Arguments:")[-1].split("-")[0]
#             class_name = line.split("CLASS")[-1].split(":")[0].replace(" ", "")
#             method_name = line.split("CLASS")[-1].split(":")[1].replace(" ", "")[:-3]
#             begin_line, end_line = method_metadata.split("-")[-1].split(",")
#             del method_text[0]
#             method_content = "".join(method_text)
#             method_text = None
#             end_method_line = True
#             begin_method_line = False
#
#             try:
#                 yield (method_content,
#                       (int(begin_line),
#                        int(end_line)),
#                        class_name,
#                        method_name,
#                        NodeType.METHOD,
#                        metadata)
#             except Exception as e:
#                 yield (None, None, None, None, None, None)
#
#         if isinstance(method_text, list):
#             if begin_method_line:
#                 begin_method_line = False
#                 continue
#             if end_method_line:
#                 continue
#             method_text.append(line)
#
#
#
# Relationship 5 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 6 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 7 -> 68684b0a-ba28-4a82-8488-f9ce0d5b24cd:
#      def node_type(self):
#         return self._type
#
#
#
# Relationship 8 -> 1e137a39-99d0-42fe-9e6d-70bd259d7c2e:
#      def add_relationship(self, node: Type['BaseNode'], relationship_type: NodeRelationshipType, line_of_occurence: Optional[int] | None = None) -> None:
#         relationship_type = relationship_type.value
#         if relationship_type not in self.__node_relationships:
#             self.__node_relationships[relationship_type] = {node.id: [line_of_occurence]}
#         else:
#             if node.id in self.__node_relationships[relationship_type]:
#                 self.__node_relationships[relationship_type][node.id].append(line_of_occurence)
#             else:
#                 self.__node_relationships[relationship_type][node.id] = [line_of_occurence]
#
#
#
# Relationship 9 -> 05abe11f-2eed-42e3-bd2b-c104e7b11fbf:
#      def tmp_folder(self):
#         return self._tmp_folder
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# BaseNode(node_type = NodeType.METHOD, metadata = {'hash': 'b3c7492e3f139b5710b211bfe973c5ea1bb2681f8689574343934b6fb00ebc3e', 'lines_of_code': (135, 199), 'additional_metadata': {'arguments': 'self', 'method_name': '_create_relationships_of_nodes'}})
# Text of this node:
#      def _create_relationships_of_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#
#         nodes_of_files_dict = self._create_nodes()
#         nodes_of_files = []
#         for _, nodes_file in nodes_of_files_dict.items():
#             nodes_of_files.extend(list(nodes_file.values()))
#
#         tmp_folder = self._file_handler.tmp_folder
#
#         fields = ('class_name', 'function_name', 'method_name')
#         name_file = os.path.join(tmp_folder, "names.txt")
#         relationships_file = os.path.join(tmp_folder, "node_relationships.txt")
#
#         nodes = []
#         with open(name_file, "w") as names_file:
#             for field in fields:
#                 get_nodes_of_field = lambda n: [x for x in n if x.metadata['additional_metadata'].get(field) is not None]
#                 nodes_of_field = get_nodes_of_field(nodes_of_files)
#                 nodes.extend(nodes_of_field)
#             for node in nodes:
#                 node_metadata = node.metadata['additional_metadata']
#                 for field in fields:
#                     name = node_metadata.get(field)
#                     if name is None or re.match(self._not_valid_relationships_to_look_pattern, name): continue
#                     names_file.write(f"{name} {node.id} {node.file}\n")
#
#         for path in self._files_path:
#             command = f"./scripts/python-scripts/find-node-relationships.sh {name_file} {path} >> {relationships_file} 2> /dev/null"
#             subprocess.run(["bash", "-c", command])
#
#         with open(relationships_file, "r") as node_relationship_file:
#             lines = node_relationship_file.readlines()
#
#         start = False
#         get_node = lambda id_: [node for node in nodes_of_files if node.id == id_]
#         for line in lines:
#             if line.startswith("#- BEGIN"):
#
#                 start = True
#                 node_id = line.split(" ")[-2].strip()
#
#             elif line.startswith("#- END"):
#                 start = False
#
#             if start:
#                 parts = line.split(":")[-1].split("-")
#                 if len(parts) > 2:
#                     file_path = "-".join(parts[:-1]).strip()
#                     line_of_code = parts[-1].strip()
#                 else:
#                     file_path, line_of_code = line.split(":")[-1].split("-")[0].strip(), line.split(":")[-1].split("-")[-1].strip()
#                 if "#" in file_path: continue
#                 nodes_of_file = nodes_of_files_dict[file_path]
#                 node_relationship_with, = get_node(node_id)
#
#                 for node in nodes_of_file.values():
#
#                     lines_of_code = node.metadata.get('lines_of_code')
#                     is_node_relationsihp_with_its_child_node = node.check_relationship(node_relationship_with, relationship_type=NodeRelationshipType.CHILD)
#
#                     if lines_of_code is None or node == node_relationship_with or is_node_relationsihp_with_its_child_node: continue
#
#                     if int(lines_of_code[0]) <= int(line_of_code) <= int(lines_of_code[1]):
#                         node.add_relationship(node_relationship_with, NodeRelationshipType.OTHER, line_of_code)
#
#         self._file_handler.delete_tmp_folder()
#         return nodes_of_files_dict
#
# Relationships of this node:
#
# Relationship 1 -> e0ea3d88-d33f-46c9-b30c-00df0cd31f6b:
#  class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
#
#
# Relationship 2 -> 97fe122f-398b-4c5c-b99c-8368d6fad0eb:
#      def id(self):
#         return self.__uuid
#
#
#
# Relationship 3 -> e7d40808-9fdd-455a-9250-50da570ce094:
#      def file(self):
#         return self._file
#
#
#
# Relationship 4 -> 4ce1fcdc-fd26-44a0-bcbe-5baf8ac77f8b:
#      def relationships(self):
#         return self.__node_relationships
#
#
#
# Relationship 5 -> 1e137a39-99d0-42fe-9e6d-70bd259d7c2e:
#      def add_relationship(self, node: Type['BaseNode'], relationship_type: NodeRelationshipType, line_of_occurence: Optional[int] | None = None) -> None:
#         relationship_type = relationship_type.value
#         if relationship_type not in self.__node_relationships:
#             self.__node_relationships[relationship_type] = {node.id: [line_of_occurence]}
#         else:
#             if node.id in self.__node_relationships[relationship_type]:
#                 self.__node_relationships[relationship_type][node.id].append(line_of_occurence)
#             else:
#                 self.__node_relationships[relationship_type][node.id] = [line_of_occurence]
#
#
#
# Relationship 6 -> c487d933-c575-4f40-82c2-3a4d7f1fff55:
#      def check_relationship(self, node: Type['BaseNode'], relationship_type: NodeRelationshipType) -> bool:
#         try:
#             return node.id in self.__node_relationships[relationship_type.value]
#         except KeyError:
#             return False
#
#
#
# Relationship 7 -> 1d63817d-ef4d-4b6a-b200-dec439166250:
#      def _create_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         nodes = {}
#         for file in self._files_path:
#             try:
#                 nodes[file] = self._create_nodes_of_file(file_path=file)
#             except Exception as e:
#                 self._file_handler.delete_tmp_folder()
#                 raise e
#         return nodes
#
#
#
# Relationship 8 -> df7cd981-3e1f-4bf8-b2ab-351836d4042f:
#      def _create_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         raise NotImplementedError("You need to implement __create_nodes method.")
#
#
#
# Relationship 9 -> 05abe11f-2eed-42e3-bd2b-c104e7b11fbf:
#      def tmp_folder(self):
#         return self._tmp_folder
#
#
#
# Relationship 10 -> 7f48dbe1-cd27-4254-b6a3-3a740fc9840a:
#      def delete_tmp_folder(self) -> None:
#         shutil.rmtree(self._tmp_folder)
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------

# %%
for node_id, node in all_nodes.items():
    print(f"Node id: ", node_id + " from ", node.file)
    print(f"Content of node type: {str(node.node_type.value)}: \n")
    print(node.content)
# Out:
# Node id:  fc4c9de5-a4e7-44ec-bf1f-0c7395d67cbc from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/types.py
# Content of node type: CLASS:
#
# class NodeType(Enum):
#
#     MODULE = "MODULE"
#     METHOD = "METHOD"
#     CLASS = "CLASS"
#     FUNCTION = "FUNCTION"
#     CODE = "CODE"
#
# Node id:  60fcc69e-6b89-4d7c-897f-1b20daada38f from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/types.py
# Content of node type: CLASS:
#
# class NodeRelationshipType(Enum):
#
#     PARENT = "PARENT"
#     CHILD = "CHILD"
#     PREV = "PREV"
#     NEXT = "NEXT"
#     OTHER = "OTHER"
#     SELF = "SELF"
#
# Node id:  492d4a80-bf12-44cd-a6b3-609c5d2c1fe5 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/types.py
# Content of node type: CLASS:
#
# class FileType(Enum):
#
#     PYTHON = "PYTHON"
#
# Node id:  b6bd141d-fe86-43ec-99f8-015d863b1b64 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/types.py
# Content of node type: CLASS:
#
# class NodeMetadata(BaseModel):
#
#     hash: str
#     lines_of_code: Tuple[int, int] | None
#
# Node id:  20fb6381-6389-48cb-998c-31e33ba07809 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/types.py
# Content of node type: CODE:
#
# )
#
# Node id:  0949e53c-1a0c-4d9c-ade9-82e0aaa66097 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: CLASS:
#
# class FunctionNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, List[Type['BaseNode']] | Type['BaseNode']]] | None = None):
#
#         super(FunctionNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  8107ae3b-c2ac-4023-a8c1-54e0cc32afa0 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: CLASS:
#
# class MethodNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(MethodNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  47a124e7-dd7d-4b09-9c12-05099ad61249 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: CLASS:
#
# class ClassNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ClassNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  03ac62da-e753-4d22-a12d-6dd6158e2845 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: CLASS:
#
# class CodeNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(CodeNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  396b5614-d19b-4d0f-9db8-86a4cf95c3be from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: CLASS:
#
# class ModuleNode(BaseNode):
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ModuleNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  bd93b543-2449-4291-a692-6dd969796ede from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: METHOD:
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, List[Type['BaseNode']] | Type['BaseNode']]] | None = None):
#
#         super(FunctionNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  e9b8c803-09c6-4459-8f43-ca4868dabaf4 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: METHOD:
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(MethodNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  498ed527-5af3-4c06-8455-0e80dfedc697 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: METHOD:
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ClassNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  50d82e1b-f395-406c-ba65-ed7e5af4a8d8 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: METHOD:
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(CodeNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  d8b18fb3-2c84-459a-9e8c-0f2a49856652 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/nodes.py
# Content of node type: METHOD:
#
#      def __init__(self,
#                   text: str,
#                   file: str,
#                   node_type: NodeType,
#                   metadata: Optional[Dict[str, Any]] | None = None,
#                   id: Optional[str] | None = None,
#                   node_relationships: Optional[Dict[NodeRelationshipType, Type['BaseNode']]] | None = None):
#
#         super(ModuleNode, self).__init__(text=text, metadata=metadata, id=id, node_relationships=node_relationships, node_type=node_type, file=file)
#
# Node id:  1376baed-db24-4310-b974-a46216859e4c from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: CLASS:
#
#
# Node id:  cab906aa-a92f-4f92-874a-6a360dd3485e from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: CLASS:
#
# class BaseNodeRelationship(ABC):
#
#     def __init__(self, node: BaseNode):
#         self._node = node
#
#         self._parent = None
#         self._childs = []
#         self._prev = None
#         self._next = None
#         self._other = {}
#
#     @abstractmethod
#     def create_relationship(self, node: BaseNode) -> None:
#         pass
#
# Node id:  9abc5927-116f-47cf-bdfc-d7545d8e471b from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def id(self):
#         return self.__uuid
#
# Node id:  023f73fe-ecb4-4710-8ea6-ca480f703554 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def content(self):
#         return self._text
#
# Node id:  e7cd4053-afa5-4040-bfac-be6e12a37395 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def file(self):
#         return self._file
#
# Node id:  55ecf62b-f935-4514-938a-98803b92d9fe from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def node_type(self):
#         return self._type
#
# Node id:  d36b9d10-4d7f-490e-a552-7126192533d7 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def relationships(self):
#         return self.__node_relationships
#
# Node id:  c1feea14-d653-465b-9e19-d6e0474c23c0 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def add_relationship(self, node: Type['BaseNode'], relationship_type: NodeRelationshipType, line_of_occurence: Optional[int] | None = None) -> None:
#         relationship_type = relationship_type.value
#         if relationship_type not in self.__node_relationships:
#             self.__node_relationships[relationship_type] = {node.id: [line_of_occurence]}
#         else:
#             if node.id in self.__node_relationships[relationship_type]:
#                 self.__node_relationships[relationship_type][node.id].append(line_of_occurence)
#             else:
#                 self.__node_relationships[relationship_type][node.id] = [line_of_occurence]
#
# Node id:  c0a3364d-83fd-4d0c-902a-9be6ec5ca05a from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def filter_relationships(self, relationship_type: NodeRelationshipType) -> List[Tuple[Type['BaseNode'], int | None]] | List:
#         relationship_type = relationship_type.value
#         filtered_relationships = [rel for rel_type, rel in self.__node_relationships.items() if rel_type == relationship_type]
#         if len(filtered_relationships) > 0:
#             return filtered_relationships[0]
#         return []
#
# Node id:  b74cfa2e-82b5-417c-91ef-1ad338a97527 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def check_relationship(self, node: Type['BaseNode'], relationship_type: NodeRelationshipType) -> bool:
#         try:
#             return node.id in self.__node_relationships[relationship_type.value]
#         except KeyError:
#             return False
#
# Node id:  fe542e6d-21c5-46c6-aa5d-963d0affc430 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def __repr__(self) -> str:
#         return f"BaseNode(node_type = {self.node_type}, metadata = {self.metadata})"
#
# Node id:  f933c8ab-904c-4807-8945-f325f62e15f0 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def __str__(self) -> str:
#         return super().__str__()
#
# Node id:  cae28e18-395b-4727-b558-94cee7c80f4f from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def __eq__(self, node: Type['BaseNode']) -> bool:
#         return node.id == self.id
#
# Node id:  126bb439-703f-483c-9f04-c8d90d119abd from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def __init__(self, node: BaseNode):
#         self._node = node
#
#         self._parent = None
#         self._childs = []
#         self._prev = None
#         self._next = None
#         self._other = {}
#
# Node id:  b6c79748-49c2-416a-aded-7ddebbb41737 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/nodes/base.py
# Content of node type: METHOD:
#
#     def create_relationship(self, node: BaseNode) -> None:
#         pass
#
# Node id:  e3ee1a03-a0e2-413a-acd4-58db3cea2d2c from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/python_chunker.py
# Content of node type: CLASS:
#
# class PythonChunker(Chunker):
#
#     _node_type_to_node_base: Dict[NodeType, Type['BaseNode']] = {
#         NodeType.CLASS: ClassNode,
#         NodeType.CODE: CodeNode,
#         NodeType.FUNCTION: FunctionNode,
#         NodeType.METHOD: MethodNode,
#         NodeType.MODULE: ModuleNode
#     }
#
#     _not_valid_relationships_to_look_pattern = r"^__[^_]*__$"
#
#     def __init__(self, files_path: str | List[str], hash_function: Optional[Callable] | None = None):
#         super(PythonChunker, self).__init__(files_path=files_path, hash_function=hash_function)
#
#     def _create_nodes_of_file(self, file_path: str) -> Dict[str, Type['BaseNode']]:
#
#         tmp_folder = self._file_handler.tmp_folder
#         if file_path.startswith("."): file_path = file_path[2:]
#         elif file_path.startswith(".."): file_path = file_path[3:]
#         file_name = file_path.replace("/", "_").split(".")[0]
#         command = f"./scripts/python-scripts/generate-node-metadata.sh {file_path} {tmp_folder}/{file_name}_info.txt > {tmp_folder}/{file_name}_final.txt 2> /dev/null"
#         subprocess.run(["bash", "-c", command])
#
#         nodes = {}
#         hashes = set()
#         classes_names_to_uuids = {}
#
#         for (code, lines_of_code, class_name, function_or_method_name, node_type, metadata) in create_nodes_from_file(f"{tmp_folder}/{file_name}_final.txt"):
#             if code is None or lines_of_code is None:
#                 continue
#             remove_commas_spaces_and_new_lines = code.replace(",", "").replace("\n", "").strip().replace(" ", "")
#             try:
#                 int(remove_commas_spaces_and_new_lines)
#                 continue
#             except Exception:
#                 pass
#
#             hash = self._hash_function(text=code)
#             if hash in hashes: continue
#             hashes.add(hash)
#             node_class = self._node_type_to_node_base[node_type]
#             node_object = node_class(
#                 text=code,
#                 node_type=node_type,
#                 file=file_path
#             )
#
#             if node_type == NodeType.CLASS:
#                 classes_names_to_uuids[class_name.replace(" ", "")] = node_object.id
#                 uuid_of_parent_node = None
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'parent_class': metadata.strip(), 'class_name': class_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.METHOD:
#                 uuid_of_parent_node = classes_names_to_uuids[class_name.replace(" ", "")]
#                 parent_node = nodes[uuid_of_parent_node]
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'arguments': metadata.strip(), 'method_name': function_or_method_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 node_object.add_relationship(parent_node, relationship_type=NodeRelationshipType.PARENT)
#                 parent_node.add_relationship(node_object, relationship_type=NodeRelationshipType.CHILD)
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.FUNCTION:
#
#                 node_metadata = NodeMetadata(
#                     hash=hash, lines_of_code=lines_of_code, additional_metadata={'arguments': metadata.strip(), 'function_name': function_or_method_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.CODE:
#                 node_metadata = NodeMetadata(
#                     hash=hash, lines_of_code=lines_of_code, additional_metadata=metadata if metadata else {}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.MODULE:
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'modules': metadata if metadata else {}}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#         return nodes
#
#     def _create_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         nodes = {}
#         for file in self._files_path:
#             try:
#                 nodes[file] = self._create_nodes_of_file(file_path=file)
#             except Exception as e:
#                 self._file_handler.delete_tmp_folder()
#                 raise e
#         return nodes
#
#     def find_relationships(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         try:
#             return self._create_relationships_of_nodes()
#         except Exception as e:
#             self._file_handler.delete_tmp_folder()
#             raise e
#
#     def _create_relationships_of_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#
#         nodes_of_files_dict = self._create_nodes()
#         nodes_of_files = []
#         for _, nodes_file in nodes_of_files_dict.items():
#             nodes_of_files.extend(list(nodes_file.values()))
#
#         tmp_folder = self._file_handler.tmp_folder
#
#         fields = ('class_name', 'function_name', 'method_name')
#         name_file = os.path.join(tmp_folder, "names.txt")
#         relationships_file = os.path.join(tmp_folder, "node_relationships.txt")
#
#         nodes = []
#         with open(name_file, "w") as names_file:
#             for field in fields:
#                 get_nodes_of_field = lambda n: [x for x in n if x.metadata['additional_metadata'].get(field) is not None]
#                 nodes_of_field = get_nodes_of_field(nodes_of_files)
#                 nodes.extend(nodes_of_field)
#             for node in nodes:
#                 node_metadata = node.metadata['additional_metadata']
#                 for field in fields:
#                     name = node_metadata.get(field)
#                     if name is None or re.match(self._not_valid_relationships_to_look_pattern, name): continue
#                     names_file.write(f"{name} {node.id} {node.file}\n")
#
#         for path in self._files_path:
#             command = f"./scripts/python-scripts/find-node-relationships.sh {name_file} {path} >> {relationships_file} 2> /dev/null"
#             subprocess.run(["bash", "-c", command])
#
#         with open(relationships_file, "r") as node_relationship_file:
#             lines = node_relationship_file.readlines()
#
#         start = False
#         get_node = lambda id_: [node for node in nodes_of_files if node.id == id_]
#         for line in lines:
#             if line.startswith("#- BEGIN"):
#
#                 start = True
#                 node_id = line.split(" ")[-2].strip()
#
#             elif line.startswith("#- END"):
#                 start = False
#
#             if start:
#                 parts = line.split(":")[-1].split("-")
#                 if len(parts) > 2:
#                     file_path = "-".join(parts[:-1]).strip()
#                     line_of_code = parts[-1].strip()
#                 else:
#                     file_path, line_of_code = line.split(":")[-1].split("-")[0].strip(), line.split(":")[-1].split("-")[-1].strip()
#                 if "#" in file_path: continue
#                 nodes_of_file = nodes_of_files_dict[file_path]
#                 node_relationship_with, = get_node(node_id)
#
#                 for node in nodes_of_file.values():
#
#                     lines_of_code = node.metadata.get('lines_of_code')
#                     is_node_relationsihp_with_its_child_node = node.check_relationship(node_relationship_with, relationship_type=NodeRelationshipType.CHILD)
#
#                     if lines_of_code is None or node == node_relationship_with or is_node_relationsihp_with_its_child_node: continue
#
#                     if int(lines_of_code[0]) <= int(line_of_code) <= int(lines_of_code[1]):
#                         node.add_relationship(node_relationship_with, NodeRelationshipType.OTHER, line_of_code)
#
#         self._file_handler.delete_tmp_folder()
#         return nodes_of_files_dict
#
# Node id:  811c9cec-56ec-42b4-b092-f6270b3828fa from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/python_chunker.py
# Content of node type: METHOD:
#
#     def __init__(self, files_path: str | List[str], hash_function: Optional[Callable] | None = None):
#         super(PythonChunker, self).__init__(files_path=files_path, hash_function=hash_function)
#
# Node id:  133dd84a-932e-4f89-a04a-cd56681d5aad from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/python_chunker.py
# Content of node type: METHOD:
#
#     def _create_nodes_of_file(self, file_path: str) -> Dict[str, Type['BaseNode']]:
#
#         tmp_folder = self._file_handler.tmp_folder
#         if file_path.startswith("."): file_path = file_path[2:]
#         elif file_path.startswith(".."): file_path = file_path[3:]
#         file_name = file_path.replace("/", "_").split(".")[0]
#         command = f"./scripts/python-scripts/generate-node-metadata.sh {file_path} {tmp_folder}/{file_name}_info.txt > {tmp_folder}/{file_name}_final.txt 2> /dev/null"
#         subprocess.run(["bash", "-c", command])
#
#         nodes = {}
#         hashes = set()
#         classes_names_to_uuids = {}
#
#         for (code, lines_of_code, class_name, function_or_method_name, node_type, metadata) in create_nodes_from_file(f"{tmp_folder}/{file_name}_final.txt"):
#             if code is None or lines_of_code is None:
#                 continue
#             remove_commas_spaces_and_new_lines = code.replace(",", "").replace("\n", "").strip().replace(" ", "")
#             try:
#                 int(remove_commas_spaces_and_new_lines)
#                 continue
#             except Exception:
#                 pass
#
#             hash = self._hash_function(text=code)
#             if hash in hashes: continue
#             hashes.add(hash)
#             node_class = self._node_type_to_node_base[node_type]
#             node_object = node_class(
#                 text=code,
#                 node_type=node_type,
#                 file=file_path
#             )
#
#             if node_type == NodeType.CLASS:
#                 classes_names_to_uuids[class_name.replace(" ", "")] = node_object.id
#                 uuid_of_parent_node = None
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'parent_class': metadata.strip(), 'class_name': class_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.METHOD:
#                 uuid_of_parent_node = classes_names_to_uuids[class_name.replace(" ", "")]
#                 parent_node = nodes[uuid_of_parent_node]
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'arguments': metadata.strip(), 'method_name': function_or_method_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 node_object.add_relationship(parent_node, relationship_type=NodeRelationshipType.PARENT)
#                 parent_node.add_relationship(node_object, relationship_type=NodeRelationshipType.CHILD)
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.FUNCTION:
#
#                 node_metadata = NodeMetadata(
#                     hash=hash, lines_of_code=lines_of_code, additional_metadata={'arguments': metadata.strip(), 'function_name': function_or_method_name.strip()}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.CODE:
#                 node_metadata = NodeMetadata(
#                     hash=hash, lines_of_code=lines_of_code, additional_metadata=metadata if metadata else {}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#             elif node_type == NodeType.MODULE:
#                 node_metadata = NodeMetadata(
#                     hash=hash,
#                     lines_of_code=lines_of_code,
#                     additional_metadata={'modules': metadata if metadata else {}}
#                 )
#                 node_object.metadata = node_metadata.model_dump()
#                 nodes[node_object.id] = node_object
#
#         return nodes
#
# Node id:  0bf26ac7-0375-42fc-8e92-6c9ab3ff7e92 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/python_chunker.py
# Content of node type: METHOD:
#
#     def _create_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         nodes = {}
#         for file in self._files_path:
#             try:
#                 nodes[file] = self._create_nodes_of_file(file_path=file)
#             except Exception as e:
#                 self._file_handler.delete_tmp_folder()
#                 raise e
#         return nodes
#
# Node id:  bfe3969e-3d50-4788-9531-c5a26ce3cd62 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/python_chunker.py
# Content of node type: METHOD:
#
#     def find_relationships(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         try:
#             return self._create_relationships_of_nodes()
#         except Exception as e:
#             self._file_handler.delete_tmp_folder()
#             raise e
#
# Node id:  2787b6b4-62e1-483a-95f2-2dcc5a8012f4 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/python_chunker.py
# Content of node type: METHOD:
#
#     def _create_relationships_of_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#
#         nodes_of_files_dict = self._create_nodes()
#         nodes_of_files = []
#         for _, nodes_file in nodes_of_files_dict.items():
#             nodes_of_files.extend(list(nodes_file.values()))
#
#         tmp_folder = self._file_handler.tmp_folder
#
#         fields = ('class_name', 'function_name', 'method_name')
#         name_file = os.path.join(tmp_folder, "names.txt")
#         relationships_file = os.path.join(tmp_folder, "node_relationships.txt")
#
#         nodes = []
#         with open(name_file, "w") as names_file:
#             for field in fields:
#                 get_nodes_of_field = lambda n: [x for x in n if x.metadata['additional_metadata'].get(field) is not None]
#                 nodes_of_field = get_nodes_of_field(nodes_of_files)
#                 nodes.extend(nodes_of_field)
#             for node in nodes:
#                 node_metadata = node.metadata['additional_metadata']
#                 for field in fields:
#                     name = node_metadata.get(field)
#                     if name is None or re.match(self._not_valid_relationships_to_look_pattern, name): continue
#                     names_file.write(f"{name} {node.id} {node.file}\n")
#
#         for path in self._files_path:
#             command = f"./scripts/python-scripts/find-node-relationships.sh {name_file} {path} >> {relationships_file} 2> /dev/null"
#             subprocess.run(["bash", "-c", command])
#
#         with open(relationships_file, "r") as node_relationship_file:
#             lines = node_relationship_file.readlines()
#
#         start = False
#         get_node = lambda id_: [node for node in nodes_of_files if node.id == id_]
#         for line in lines:
#             if line.startswith("#- BEGIN"):
#
#                 start = True
#                 node_id = line.split(" ")[-2].strip()
#
#             elif line.startswith("#- END"):
#                 start = False
#
#             if start:
#                 parts = line.split(":")[-1].split("-")
#                 if len(parts) > 2:
#                     file_path = "-".join(parts[:-1]).strip()
#                     line_of_code = parts[-1].strip()
#                 else:
#                     file_path, line_of_code = line.split(":")[-1].split("-")[0].strip(), line.split(":")[-1].split("-")[-1].strip()
#                 if "#" in file_path: continue
#                 nodes_of_file = nodes_of_files_dict[file_path]
#                 node_relationship_with, = get_node(node_id)
#
#                 for node in nodes_of_file.values():
#
#                     lines_of_code = node.metadata.get('lines_of_code')
#                     is_node_relationsihp_with_its_child_node = node.check_relationship(node_relationship_with, relationship_type=NodeRelationshipType.CHILD)
#
#                     if lines_of_code is None or node == node_relationship_with or is_node_relationsihp_with_its_child_node: continue
#
#                     if int(lines_of_code[0]) <= int(line_of_code) <= int(lines_of_code[1]):
#                         node.add_relationship(node_relationship_with, NodeRelationshipType.OTHER, line_of_code)
#
#         self._file_handler.delete_tmp_folder()
#         return nodes_of_files_dict
#
# Node id:  dd116ffb-a4d9-4b87-8657-f5ebf93cb8c5 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/base.py
# Content of node type: CLASS:
#
# class Chunker(ABC):
#
#     __extensions_to_type = {'*.py'}
#     temp_file_handler = TempFileHandler
#
#     def __init__(self, files_path: str | List[str],
#                  hash_function: Optional[Callable] | None = None,
#                  pattern: str = "*.py"):
#
#         if pattern not in self.__extensions_to_type:
#             raise ValueError(f"Your pattern is not implemented yet. Available: {self.__extensions_to_type}")
#         _files_path = files_path if isinstance(files_path, list) else [files_path]
#         self._files_path = []
#         for file_path in _files_path:
#             self._files_path.extend(self._recursive_retrieval_of_files(file_path=file_path))
#
#         self._hash_function = hash_function if hash_function else self._default_hash_function
#         self._file_handler = self.temp_file_handler()
#         print("Imported files: ", self._files_path)
#
#     @abstractmethod
#     def _create_nodes_of_file(self, file_path: str) -> Dict[str, Type['BaseNode']]:
#         raise NotImplementedError("You need to implement _create_nodes_of_file method.")
#
#     @abstractmethod
#     def _create_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         raise NotImplementedError("You need to implement __create_nodes method.")
#
#     @staticmethod
#     def _default_hash_function(text: str) -> str:
#
#         hasher = hashlib.new('sha256')
#         text = text.replace("\n", "").replace(" ", "")
#         if len(text) < 1:
#             return ''
#         hasher.update(text.encode('utf-8'))
#         return hasher.hexdigest()
#
#     @staticmethod
#     def _recursive_retrieval_of_files(file_path: str, pattern: str="*.py") -> List[str]:
#
#         if file_path.endswith(".py"):
#             return [file_path]
#
#         python_files = []
#         for path, _, files in os.walk(file_path):
#             if file_path.startswith("."):
#                 root_path = path.split("/")[-1]
#                 if root_path.startswith("."): continue
#
#             for name in files:
#                 if ".venv/" in path: continue
#                 if fnmatch(name, pattern) and name != "__init__.py":
#                     python_files.append(os.path.join(path, name))
#
#         python_files = [os.path.abspath(path) for path in python_files]
#         return python_files
#
# Node id:  7b640f1c-2c7e-4fbb-bb4f-85b6b3de7b78 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/base.py
# Content of node type: METHOD:
#
#     def __init__(self, files_path: str | List[str],
#                  hash_function: Optional[Callable] | None = None,
#                  pattern: str = "*.py"):
#
#         if pattern not in self.__extensions_to_type:
#             raise ValueError(f"Your pattern is not implemented yet. Available: {self.__extensions_to_type}")
#         _files_path = files_path if isinstance(files_path, list) else [files_path]
#         self._files_path = []
#         for file_path in _files_path:
#             self._files_path.extend(self._recursive_retrieval_of_files(file_path=file_path))
#
#         self._hash_function = hash_function if hash_function else self._default_hash_function
#         self._file_handler = self.temp_file_handler()
#         print("Imported files: ", self._files_path)
#
# Node id:  3e13548d-c409-485e-a9ca-3ec2af0a9e5e from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/base.py
# Content of node type: METHOD:
#
#     def _create_nodes_of_file(self, file_path: str) -> Dict[str, Type['BaseNode']]:
#         raise NotImplementedError("You need to implement _create_nodes_of_file method.")
#
# Node id:  8a130dc3-23e7-4e1a-bbbb-b9504b4ad63e from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/base.py
# Content of node type: METHOD:
#
#     def _create_nodes(self) -> Dict[str, Dict[str, Type['BaseNode']]]:
#         raise NotImplementedError("You need to implement __create_nodes method.")
#
# Node id:  efe87981-d117-41a7-9438-0b301959c0e6 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/base.py
# Content of node type: METHOD:
#
#     def _default_hash_function(text: str) -> str:
#
#         hasher = hashlib.new('sha256')
#         text = text.replace("\n", "").replace(" ", "")
#         if len(text) < 1:
#             return ''
#         hasher.update(text.encode('utf-8'))
#         return hasher.hexdigest()
#
# Node id:  e79aaace-cbc2-4c5b-b585-332efb513e04 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/chunkers/base.py
# Content of node type: METHOD:
#
#     def _recursive_retrieval_of_files(file_path: str, pattern: str="*.py") -> List[str]:
#
#         if file_path.endswith(".py"):
#             return [file_path]
#
#         python_files = []
#         for path, _, files in os.walk(file_path):
#             if file_path.startswith("."):
#                 root_path = path.split("/")[-1]
#                 if root_path.startswith("."): continue
#
#             for name in files:
#                 if ".venv/" in path: continue
#                 if fnmatch(name, pattern) and name != "__init__.py":
#                     python_files.append(os.path.join(path, name))
#
#         python_files = [os.path.abspath(path) for path in python_files]
#         return python_files
#
# Node id:  2376a3f1-2435-4526-8f62-95cbfdf7695c from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/files_handler.py
# Content of node type: CLASS:
#
# class TempFileHandler:
#
#     def __init__(self):
#         self._tmp_folder = self._create_tmp_folder()
#
#     @property
#     def tmp_folder(self):
#         return self._tmp_folder
#
#     def create(self) -> Type['TempFileHandler']:
#         self._tmp_folder = self._create_tmp_folder()
#         return self
#
#     def _create_tmp_folder(self) -> str:
#         return tempfile.mkdtemp()
#
#     def delete_tmp_folder(self) -> None:
#         shutil.rmtree(self._tmp_folder)
#
# Node id:  625c62be-0bf6-4b24-9257-ab832699c122 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/files_handler.py
# Content of node type: METHOD:
#
#     def __init__(self):
#         self._tmp_folder = self._create_tmp_folder()
#
# Node id:  a4bf42e3-f243-4d73-8a87-b5349cfaa31c from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/files_handler.py
# Content of node type: METHOD:
#
#     def tmp_folder(self):
#         return self._tmp_folder
#
# Node id:  2d502d78-b1ba-4572-9704-ffac62b1907e from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/files_handler.py
# Content of node type: METHOD:
#
#     def create(self) -> Type['TempFileHandler']:
#         self._tmp_folder = self._create_tmp_folder()
#         return self
#
# Node id:  adc742ee-86a5-4bb1-aa4e-8247b0e353c6 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/files_handler.py
# Content of node type: METHOD:
#
#     def _create_tmp_folder(self) -> str:
#         return tempfile.mkdtemp()
#
# Node id:  adc4e25e-2206-46b4-b60a-dad8862af684 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/files_handler.py
# Content of node type: METHOD:
#
#     def delete_tmp_folder(self) -> None:
#         shutil.rmtree(self._tmp_folder)
#
# Node id:  9706f761-88e6-4755-8163-0cd455e1d728 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/nodes_utils.py
# Content of node type: FUNCTION:
#
# def create_nodes_from_file(file: str) -> Generator[Tuple, None, None]:
#     lines = open(file).readlines()
#     modules_text = None
#     class_text = None
#     method_text = None
#     function_text = None
#     free_code = None
#
#     # TODO -> refactor this into smaller functions
#
#     for line in lines:
#
#         if line.startswith(Delimiter.module_delimiter[Pointer.start]):
#             modules_text = []
#             class_text = None
#             function_text = None
#             method_text = None
#             free_code = None
#
#             begin_module_line = True
#             end_module_line = False
#
#         elif line.startswith(Delimiter.class_delimiter[Pointer.start]):
#             class_text = []
#             modules_text = None
#             function_text = None
#             method_text = None
#             free_code = None
#
#             begin_class_line = True
#             end_class_line = False
#             class_name = line.replace(" ", "").split(":")[-1][:-3]
#
#
#         elif line.startswith(Delimiter.function_delimiter[Pointer.start]):
#
#             function_text = []
#             method_text = None
#             class_text = None
#             modules_text = None
#             free_code = None
#
#             begin_function_line = True
#             end_function_line = False
#
#         elif line.startswith(Delimiter.free_code_delimiter[Pointer.start]):
#
#             free_code = []
#             function_text = None
#             method_text = None
#             class_text = None
#             modules_text = None
#
#             begin_free_code = True
#             end_free_code = False
#
#         elif line.startswith(Delimiter.module_delimiter[Pointer.end]) and isinstance(modules_text, list):
#             modules_content = "".join(modules_text)
#             modules_text = None
#             end_module_line = True
#             yield modules_content, None , None, None, NodeType.MODULE, None
#
#         elif line.startswith(Delimiter.class_delimiter[Pointer.end]) and isinstance(class_text, list):
#             class_metadata = class_text[0].split(":")[-1]
#
#             try:
#                 begin_line, end_line = class_metadata.split("-")[-1].split(",")
#                 begin_line = begin_line.replace("\n", "")
#                 end_line = end_line.replace("\n", "")
#                 if not len(end_line.strip()):
#                     end_line = int(begin_line) + 1
#             except ValueError:
#                 begin_line = class_metadata.split("-")[-1].split(",")[0]
#                 end_line = int(begin_line) + 1
#
#             metadata = class_metadata.split(":")[-1].split("-")[0]
#             del class_text[0]
#             class_content = "".join(class_text)
#             class_text = None
#             end_class_line = True
#             begin_class_line = False
#             yield class_content, (int(begin_line), int(end_line)), class_name, None, NodeType.CLASS, metadata
#
#         elif line.startswith(Delimiter.function_delimiter[Pointer.end]) and isinstance(function_text, list):
#
#             end_function_line = True
#             begin_function_line = False
#             function_metadata = function_text[0]
#             metadata = function_text[0].split("Arguments:")[-1].split("-")[0]
#             function_name = line.split("FUNCTION:")[-1].replace(" ", "")[:-3]
#             begin_line, end_line = function_metadata.split("-")[-1].split(",")
#             if not len(end_line.strip()): end_line = int(begin_line) + 1
#             del function_text[0]
#             function_content = "".join(function_text)
#             function_text = None
#             yield (function_content,
#                   (int(begin_line),
#                    int(end_line)),
#                    None,
#                    function_name,
#                    NodeType.FUNCTION,
#                    metadata)
#
#         elif line.startswith(Delimiter.free_code_delimiter[Pointer.end]) and isinstance(free_code, list):
#             end_free_code = True
#             begin_free_code = False
#             code_metadata = free_code[0]
#             begin_line, end_line = code_metadata.split(":")[-1].split(",")
#             del free_code[0]
#             code_content = "".join(free_code)
#             free_code = None
#             yield (code_content,
#                   (int(begin_line),
#                    int(end_line)),
#                    None,
#                    None,
#                    NodeType.CODE,
#                    None)
#
#         if isinstance(modules_text, list):
#             if begin_module_line:
#                 begin_module_line = False
#                 continue
#             if end_module_line:
#                 continue
#
#             modules_text.append(line)
#
#         elif isinstance(class_text, list):
#             if begin_class_line:
#                 begin_class_line = False
#                 continue
#             if end_class_line:
#                 continue
#             class_text.append(line)
#
#         elif isinstance(function_text, list):
#             if begin_function_line:
#                 begin_function_line = False
#                 continue
#             if end_function_line:
#                 continue
#             function_text.append(line)
#
#         elif isinstance(free_code, list):
#             if begin_free_code:
#                 begin_free_code = False
#                 continue
#             if end_free_code:
#                 continue
#             free_code.append(line)
#
#
#     for line in lines:
#
#         if line.startswith(Delimiter.method_delimiter[Pointer.start]):
#             method_text = []
#             class_text = None
#             modules_text = None
#             function_text = None
#             free_code = None
#
#             begin_method_line = True
#             end_method_line = False
#
#         elif line.startswith(Delimiter.method_delimiter[Pointer.end]) and isinstance(method_text, list):
#             method_metadata = method_text[0]
#             metadata = method_metadata.split("Arguments:")[-1].split("-")[0]
#             class_name = line.split("CLASS")[-1].split(":")[0].replace(" ", "")
#             method_name = line.split("CLASS")[-1].split(":")[1].replace(" ", "")[:-3]
#             begin_line, end_line = method_metadata.split("-")[-1].split(",")
#             del method_text[0]
#             method_content = "".join(method_text)
#             method_text = None
#             end_method_line = True
#             begin_method_line = False
#
#             try:
#                 yield (method_content,
#                       (int(begin_line),
#                        int(end_line)),
#                        class_name,
#                        method_name,
#                        NodeType.METHOD,
#                        metadata)
#             except Exception as e:
#                 yield (None, None, None, None, None, None)
#
#         if isinstance(method_text, list):
#             if begin_method_line:
#                 begin_method_line = False
#                 continue
#             if end_method_line:
#                 continue
#             method_text.append(line)
#
# Node id:  dd84d553-de09-474f-8cb0-6359f5d69e82 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/nodes_utils.py
# Content of node type: CLASS:
#
# class Pointer:
#     start = 'start'
#     end = 'end'
#
# Node id:  a3fae9a2-94ff-4c39-97ab-3b7e13850fe3 from  /Users/Jaime/Desktop/Project-Ideas/pychunk-library/pychunk/utils/nodes_utils.py
# Content of node type: CLASS:
#
# class Delimiter:
#
#     module_delimiter = {Pointer.start: "#- BEGIN MODULES -#", Pointer.end: "#- END MODULES -#"}
#     function_delimiter = {Pointer.start: "#- BEGIN FUNCTION", Pointer.end: "#- END FUNCTION"}
#     class_delimiter = {Pointer.start: "#- BEGIN CLASS", Pointer.end: "#- END CLASS"}
#     method_delimiter = {Pointer.start: "#- BEGIN METHOD OF CLASS", Pointer.end: "#- END METHOD OF CLASS"}
#     free_code_delimiter = {Pointer.start: "#- BEGIN BLOCK OF CODE -#", Pointer.end: "#- END BLOCK OF CODE -#"}
